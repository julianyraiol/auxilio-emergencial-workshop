# %% [markdown]
# ## Workshop de Elasticsearch

# %%
from elasticsearch import Elasticsearch
import requests

# %%
es_client = Elasticsearch(
            ['cc22be710bd7431c87275d1d5882c2b0.eastus2.azure.elastic-cloud.com'],
            http_auth=('elastic', 'JDaQiDWbm5LM8zpuC9bEfA1S'),
            scheme="https",
            port=9243,
        )

# %%
es_client.info()
# Out:
# {'name': '03586b8f9d76',
#  'cluster_name': 'docker-cluster',
#  'cluster_uuid': 'kYalZn1VR7OtDlTeeQfF-Q',
#  'version': {'number': '7.9.2',
#   'build_flavor': 'default',
#   'build_type': 'docker',
#   'build_hash': 'd34da0ea4a966c4e49417f2da2f244e3e97b4e6e',
#   'build_date': '2020-09-23T00:45:33.626720Z',
#   'build_snapshot': False,
#   'lucene_version': '8.6.2',
#   'minimum_wire_compatibility_version': '6.8.0',
#   'minimum_index_compatibility_version': '6.0.0-beta1'},
#  'tagline': 'You Know, for Search'}

# %% [markdown]
# ## Conhecendo nossa base de dados

# %%
index = "auxilio-emergencial"

# %%
# Mapeamento do index
es_client.indices.get_mapping(index)
# Out:
# {'auxilio-emergencial': {'mappings': {'properties': {'codigo_municipio_ibge': {'type': 'keyword'},
#     'cpf_beneficiario': {'type': 'keyword'},
#     'cpf_responsavel': {'type': 'keyword'},
#     'enquadramento': {'type': 'keyword'},
#     'mes_disponibilizacao': {'type': 'keyword'},
#     'nis_beneficiario': {'type': 'keyword'},
#     'nis_responsavel': {'type': 'keyword'},
#     'nome_beneficiario': {'type': 'keyword'},
#     'nome_municipio': {'type': 'keyword'},
#     'nome_responsavel': {'type': 'keyword'},
#     'observacao': {'type': 'keyword'},
#     'parcela': {'type': 'keyword'},
#     'uf': {'type': 'keyword'},
#     'valor_beneficio': {'type': 'keyword'}}}}}

# %%
# Configurações do index
es_client.indices.get_settings(index)
# Out:
# {'auxilio-emergencial': {'settings': {'index': {'creation_date': '1604267663525',
#     'number_of_shards': '1',
#     'number_of_replicas': '1',
#     'uuid': 'Cs08EwQUTwWr8LTPrtqJGg',
#     'version': {'created': '7090299'},
#     'provided_name': 'auxilio-emergencial'}}}}

# %%
# Estatísticas do index
es_client.indices.stats(index)
# Out:
# {'_shards': {'total': 2, 'successful': 1, 'failed': 0},
#  '_all': {'primaries': {'docs': {'count': 8844290, 'deleted': 0},
#    'store': {'size_in_bytes': 1339383188, 'reserved_in_bytes': 0},
#    'indexing': {'index_total': 8844290,
#     'index_time_in_millis': 423024,
#     'index_current': 0,
#     'index_failed': 0,
#     'delete_total': 0,
#     'delete_time_in_millis': 0,
#     'delete_current': 0,
#     'noop_update_total': 0,
#     'is_throttled': False,
#     'throttle_time_in_millis': 0},
#    'get': {'total': 0,
#     'time_in_millis': 0,
#     'exists_total': 0,
#     'exists_time_in_millis': 0,
#     'missing_total': 0,
#     'missing_time_in_millis': 0,
#     'current': 0},
#    'search': {'open_contexts': 0,
#     'query_total': 67,
#     'query_time_in_millis': 69,
#     'query_current': 0,
#     'fetch_total': 67,
#     'fetch_time_in_millis': 143,
#     'fetch_current': 0,
#     'scroll_total': 0,
#     'scroll_time_in_millis': 0,
#     'scroll_current': 0,
#     'suggest_total': 0,
#     'suggest_time_in_millis': 0,
#     'suggest_current': 0},
#    'merges': {'current': 0,
#     'current_docs': 0,
#     'current_size_in_bytes': 0,
#     'total': 54,
#     'total_time_in_millis': 352010,
#     'total_docs': 10702611,
#     'total_size_in_bytes': 1863899242,
#     'total_stopped_time_in_millis': 0,
#     'total_throttled_time_in_millis': 44565,
#     'total_auto_throttle_in_bytes': 10761705},
#    'refresh': {'total': 461,
#     'total_time_in_millis': 60056,
#     'external_total': 452,
#     'external_total_time_in_millis': 54860,
#     'listeners': 0},
#    'flush': {'total': 8, 'periodic': 7, 'total_time_in_millis': 23465},
#    'warmer': {'current': 0, 'total': 451, 'total_time_in_millis': 10},
#    'query_cache': {'memory_size_in_bytes': 0,
#     'total_count': 0,
#     'hit_count': 0,
#     'miss_count': 0,
#     'cache_size': 0,
#     'cache_count': 0,
#     'evictions': 0},
#    'fielddata': {'memory_size_in_bytes': 0, 'evictions': 0},
#    'completion': {'size_in_bytes': 0},
#    'segments': {'count': 21,
#     'memory_in_bytes': 101876,
#     'terms_memory_in_bytes': 71904,
#     'stored_fields_memory_in_bytes': 28376,
#     'term_vectors_memory_in_bytes': 0,
#     'norms_memory_in_bytes': 0,
#     'points_memory_in_bytes': 0,
#     'doc_values_memory_in_bytes': 1596,
#     'index_writer_memory_in_bytes': 0,
#     'version_map_memory_in_bytes': 0,
#     'fixed_bit_set_memory_in_bytes': 0,
#     'max_unsafe_auto_id_timestamp': -1,
#     'file_sizes': {}},
#    'translog': {'operations': 0,
#     'size_in_bytes': 55,
#     'uncommitted_operations': 0,
#     'uncommitted_size_in_bytes': 55,
#     'earliest_last_modified_age': 0},
#    'request_cache': {'memory_size_in_bytes': 0,
#     'evictions': 0,
#     'hit_count': 19,
#     'miss_count': 45},
#    'recovery': {'current_as_source': 0,
#     'current_as_target': 0,
#     'throttle_time_in_millis': 0}},
#   'total': {'docs': {'count': 8844290, 'deleted': 0},
#    'store': {'size_in_bytes': 1339383188, 'reserved_in_bytes': 0},
#    'indexing': {'index_total': 8844290,
#     'index_time_in_millis': 423024,
#     'index_current': 0,
#     'index_failed': 0,
#     'delete_total': 0,
#     'delete_time_in_millis': 0,
#     'delete_current': 0,
#     'noop_update_total': 0,
#     'is_throttled': False,
#     'throttle_time_in_millis': 0},
#    'get': {'total': 0,
#     'time_in_millis': 0,
#     'exists_total': 0,
#     'exists_time_in_millis': 0,
#     'missing_total': 0,
#     'missing_time_in_millis': 0,
#     'current': 0},
#    'search': {'open_contexts': 0,
#     'query_total': 67,
#     'query_time_in_millis': 69,
#     'query_current': 0,
#     'fetch_total': 67,
#     'fetch_time_in_millis': 143,
#     'fetch_current': 0,
#     'scroll_total': 0,
#     'scroll_time_in_millis': 0,
#     'scroll_current': 0,
#     'suggest_total': 0,
#     'suggest_time_in_millis': 0,
#     'suggest_current': 0},
#    'merges': {'current': 0,
#     'current_docs': 0,
#     'current_size_in_bytes': 0,
#     'total': 54,
#     'total_time_in_millis': 352010,
#     'total_docs': 10702611,
#     'total_size_in_bytes': 1863899242,
#     'total_stopped_time_in_millis': 0,
#     'total_throttled_time_in_millis': 44565,
#     'total_auto_throttle_in_bytes': 10761705},
#    'refresh': {'total': 461,
#     'total_time_in_millis': 60056,
#     'external_total': 452,
#     'external_total_time_in_millis': 54860,
#     'listeners': 0},
#    'flush': {'total': 8, 'periodic': 7, 'total_time_in_millis': 23465},
#    'warmer': {'current': 0, 'total': 451, 'total_time_in_millis': 10},
#    'query_cache': {'memory_size_in_bytes': 0,
#     'total_count': 0,
#     'hit_count': 0,
#     'miss_count': 0,
#     'cache_size': 0,
#     'cache_count': 0,
#     'evictions': 0},
#    'fielddata': {'memory_size_in_bytes': 0, 'evictions': 0},
#    'completion': {'size_in_bytes': 0},
#    'segments': {'count': 21,
#     'memory_in_bytes': 101876,
#     'terms_memory_in_bytes': 71904,
#     'stored_fields_memory_in_bytes': 28376,
#     'term_vectors_memory_in_bytes': 0,
#     'norms_memory_in_bytes': 0,
#     'points_memory_in_bytes': 0,
#     'doc_values_memory_in_bytes': 1596,
#     'index_writer_memory_in_bytes': 0,
#     'version_map_memory_in_bytes': 0,
#     'fixed_bit_set_memory_in_bytes': 0,
#     'max_unsafe_auto_id_timestamp': -1,
#     'file_sizes': {}},
#    'translog': {'operations': 0,
#     'size_in_bytes': 55,
#     'uncommitted_operations': 0,
#     'uncommitted_size_in_bytes': 55,
#     'earliest_last_modified_age': 0},
#    'request_cache': {'memory_size_in_bytes': 0,
#     'evictions': 0,
#     'hit_count': 19,
#     'miss_count': 45},
#    'recovery': {'current_as_source': 0,
#     'current_as_target': 0,
#     'throttle_time_in_millis': 0}}},
#  'indices': {'auxilio-emergencial': {'uuid': 'Cs08EwQUTwWr8LTPrtqJGg',
#    'primaries': {'docs': {'count': 8844290, 'deleted': 0},
#     'store': {'size_in_bytes': 1339383188, 'reserved_in_bytes': 0},
#     'indexing': {'index_total': 8844290,
#      'index_time_in_millis': 423024,
#      'index_current': 0,
#      'index_failed': 0,
#      'delete_total': 0,
#      'delete_time_in_millis': 0,
#      'delete_current': 0,
#      'noop_update_total': 0,
#      'is_throttled': False,
#      'throttle_time_in_millis': 0},
#     'get': {'total': 0,
#      'time_in_millis': 0,
#      'exists_total': 0,
#      'exists_time_in_millis': 0,
#      'missing_total': 0,
#      'missing_time_in_millis': 0,
#      'current': 0},
#     'search': {'open_contexts': 0,
#      'query_total': 67,
#      'query_time_in_millis': 69,
#      'query_current': 0,
#      'fetch_total': 67,
#      'fetch_time_in_millis': 143,
#      'fetch_current': 0,
#      'scroll_total': 0,
#      'scroll_time_in_millis': 0,
#      'scroll_current': 0,
#      'suggest_total': 0,
#      'suggest_time_in_millis': 0,
#      'suggest_current': 0},
#     'merges': {'current': 0,
#      'current_docs': 0,
#      'current_size_in_bytes': 0,
#      'total': 54,
#      'total_time_in_millis': 352010,
#      'total_docs': 10702611,
#      'total_size_in_bytes': 1863899242,
#      'total_stopped_time_in_millis': 0,
#      'total_throttled_time_in_millis': 44565,
#      'total_auto_throttle_in_bytes': 10761705},
#     'refresh': {'total': 461,
#      'total_time_in_millis': 60056,
#      'external_total': 452,
#      'external_total_time_in_millis': 54860,
#      'listeners': 0},
#     'flush': {'total': 8, 'periodic': 7, 'total_time_in_millis': 23465},
#     'warmer': {'current': 0, 'total': 451, 'total_time_in_millis': 10},
#     'query_cache': {'memory_size_in_bytes': 0,
#      'total_count': 0,
#      'hit_count': 0,
#      'miss_count': 0,
#      'cache_size': 0,
#      'cache_count': 0,
#      'evictions': 0},
#     'fielddata': {'memory_size_in_bytes': 0, 'evictions': 0},
#     'completion': {'size_in_bytes': 0},
#     'segments': {'count': 21,
#      'memory_in_bytes': 101876,
#      'terms_memory_in_bytes': 71904,
#      'stored_fields_memory_in_bytes': 28376,
#      'term_vectors_memory_in_bytes': 0,
#      'norms_memory_in_bytes': 0,
#      'points_memory_in_bytes': 0,
#      'doc_values_memory_in_bytes': 1596,
#      'index_writer_memory_in_bytes': 0,
#      'version_map_memory_in_bytes': 0,
#      'fixed_bit_set_memory_in_bytes': 0,
#      'max_unsafe_auto_id_timestamp': -1,
#      'file_sizes': {}},
#     'translog': {'operations': 0,
#      'size_in_bytes': 55,
#      'uncommitted_operations': 0,
#      'uncommitted_size_in_bytes': 55,
#      'earliest_last_modified_age': 0},
#     'request_cache': {'memory_size_in_bytes': 0,
#      'evictions': 0,
#      'hit_count': 19,
#      'miss_count': 45},
#     'recovery': {'current_as_source': 0,
#      'current_as_target': 0,
#      'throttle_time_in_millis': 0}},
#    'total': {'docs': {'count': 8844290, 'deleted': 0},
#     'store': {'size_in_bytes': 1339383188, 'reserved_in_bytes': 0},
#     'indexing': {'index_total': 8844290,
#      'index_time_in_millis': 423024,
#      'index_current': 0,
#      'index_failed': 0,
#      'delete_total': 0,
#      'delete_time_in_millis': 0,
#      'delete_current': 0,
#      'noop_update_total': 0,
#      'is_throttled': False,
#      'throttle_time_in_millis': 0},
#     'get': {'total': 0,
#      'time_in_millis': 0,
#      'exists_total': 0,
#      'exists_time_in_millis': 0,
#      'missing_total': 0,
#      'missing_time_in_millis': 0,
#      'current': 0},
#     'search': {'open_contexts': 0,
#      'query_total': 67,
#      'query_time_in_millis': 69,
#      'query_current': 0,
#      'fetch_total': 67,
#      'fetch_time_in_millis': 143,
#      'fetch_current': 0,
#      'scroll_total': 0,
#      'scroll_time_in_millis': 0,
#      'scroll_current': 0,
#      'suggest_total': 0,
#      'suggest_time_in_millis': 0,
#      'suggest_current': 0},
#     'merges': {'current': 0,
#      'current_docs': 0,
#      'current_size_in_bytes': 0,
#      'total': 54,
#      'total_time_in_millis': 352010,
#      'total_docs': 10702611,
#      'total_size_in_bytes': 1863899242,
#      'total_stopped_time_in_millis': 0,
#      'total_throttled_time_in_millis': 44565,
#      'total_auto_throttle_in_bytes': 10761705},
#     'refresh': {'total': 461,
#      'total_time_in_millis': 60056,
#      'external_total': 452,
#      'external_total_time_in_millis': 54860,
#      'listeners': 0},
#     'flush': {'total': 8, 'periodic': 7, 'total_time_in_millis': 23465},
#     'warmer': {'current': 0, 'total': 451, 'total_time_in_millis': 10},
#     'query_cache': {'memory_size_in_bytes': 0,
#      'total_count': 0,
#      'hit_count': 0,
#      'miss_count': 0,
#      'cache_size': 0,
#      'cache_count': 0,
#      'evictions': 0},
#     'fielddata': {'memory_size_in_bytes': 0, 'evictions': 0},
#     'completion': {'size_in_bytes': 0},
#     'segments': {'count': 21,
#      'memory_in_bytes': 101876,
#      'terms_memory_in_bytes': 71904,
#      'stored_fields_memory_in_bytes': 28376,
#      'term_vectors_memory_in_bytes': 0,
#      'norms_memory_in_bytes': 0,
#      'points_memory_in_bytes': 0,
#      'doc_values_memory_in_bytes': 1596,
#      'index_writer_memory_in_bytes': 0,
#      'version_map_memory_in_bytes': 0,
#      'fixed_bit_set_memory_in_bytes': 0,
#      'max_unsafe_auto_id_timestamp': -1,
#      'file_sizes': {}},
#     'translog': {'operations': 0,
#      'size_in_bytes': 55,
#      'uncommitted_operations': 0,
#      'uncommitted_size_in_bytes': 55,
#      'earliest_last_modified_age': 0},
#     'request_cache': {'memory_size_in_bytes': 0,
#      'evictions': 0,
#      'hit_count': 19,
#      'miss_count': 45},
#     'recovery': {'current_as_source': 0,
#      'current_as_target': 0,
#      'throttle_time_in_millis': 0}}}}}

# %% [markdown]
# ## Fazendo consultas na base de dados

# %%
body = {
  "query": {
    "match_all": {}
  }
}

# %%
result = es_client.search(index=index, body=body)

print("Total de registros ", len(result["hits"]["hits"]))
result
# Out:
# Total de registros  10
# {'took': 1,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'gte'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'GpfOhXUB0pJdUuAdVmBG',
#     '_score': 1.0,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'PE',
#      'codigo_municipio_ibge': 2611903.0,
#      'nome_municipio': 'RIO FORMOSO',
#      'nis_beneficiario': 0,
#      'cpf_beneficiario': '***.500.374-**',
#      'nome_beneficiario': 'RIVALDO SANTOS TIBURCIO',
#      'nis_responsavel': -2,
#      'cpf_responsavel': None,
#      'nome_responsavel': 'Não se aplica',
#      'enquadramento': 'EXTRA CADUN',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '600,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'G5fOhXUB0pJdUuAdVmBG',
#     '_score': 1.0,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'PE',
#      'codigo_municipio_ibge': 2611903.0,
#      'nome_municipio': 'RIO FORMOSO',
#      'nis_beneficiario': 0,
#      'cpf_beneficiario': '***.025.374-**',
#      'nome_beneficiario': 'RIVANILDA BATISTA DE OLIVEIRA',
#      'nis_responsavel': -2,
#      'cpf_responsavel': None,
#      'nome_responsavel': 'Não se aplica',
#      'enquadramento': 'EXTRA CADUN',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '1200,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'HJfOhXUB0pJdUuAdVmBG',
#     '_score': 1.0,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'PE',
#      'codigo_municipio_ibge': 2611903.0,
#      'nome_municipio': 'RIO FORMOSO',
#      'nis_beneficiario': 0,
#      'cpf_beneficiario': '***.245.724-**',
#      'nome_beneficiario': 'RIVANILDO SEBASTIAO DA SILVA',
#      'nis_responsavel': -2,
#      'cpf_responsavel': None,
#      'nome_responsavel': 'Não se aplica',
#      'enquadramento': 'EXTRA CADUN',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '600,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'HZfOhXUB0pJdUuAdVmBG',
#     '_score': 1.0,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'PE',
#      'codigo_municipio_ibge': 2611903.0,
#      'nome_municipio': 'RIO FORMOSO',
#      'nis_beneficiario': 16579842491,
#      'cpf_beneficiario': '***.510.494-**',
#      'nome_beneficiario': 'RIZOMAR MARIA DA SILVA',
#      'nis_responsavel': 16579842491,
#      'cpf_responsavel': '***.510.494-**',
#      'nome_responsavel': 'RIZOMAR MARIA DA SILVA',
#      'enquadramento': 'BOLSA FAMILIA',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '1200,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'HpfOhXUB0pJdUuAdVmBG',
#     '_score': 1.0,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'PE',
#      'codigo_municipio_ibge': 2611903.0,
#      'nome_municipio': 'RIO FORMOSO',
#      'nis_beneficiario': 16573547773,
#      'cpf_beneficiario': '***.808.374-**',
#      'nome_beneficiario': 'RIZONETE MARIA DO CARMO',
#      'nis_responsavel': -2,
#      'cpf_responsavel': None,
#      'nome_responsavel': 'Não se aplica',
#      'enquadramento': 'CADUN NAO BOLSA',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '600,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'H5fOhXUB0pJdUuAdVmBG',
#     '_score': 1.0,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'PE',
#      'codigo_municipio_ibge': 2611903.0,
#      'nome_municipio': 'RIO FORMOSO',
#      'nis_beneficiario': 16699033418,
#      'cpf_beneficiario': '***.765.614-**',
#      'nome_beneficiario': 'RIZONILDO FERREIRA DOS SANTOS',
#      'nis_responsavel': -2,
#      'cpf_responsavel': None,
#      'nome_responsavel': 'Não se aplica',
#      'enquadramento': 'CADUN NAO BOLSA',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '600,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'IJfOhXUB0pJdUuAdVmBG',
#     '_score': 1.0,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'PE',
#      'codigo_municipio_ibge': 2611903.0,
#      'nome_municipio': 'RIO FORMOSO',
#      'nis_beneficiario': 0,
#      'cpf_beneficiario': '***.812.844-**',
#      'nome_beneficiario': 'ROANNA ROCELI NASCIMENTO SANTOS',
#      'nis_responsavel': -2,
#      'cpf_responsavel': None,
#      'nome_responsavel': 'Não se aplica',
#      'enquadramento': 'EXTRA CADUN',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '600,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'IZfOhXUB0pJdUuAdVmBG',
#     '_score': 1.0,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'PE',
#      'codigo_municipio_ibge': 2611903.0,
#      'nome_municipio': 'RIO FORMOSO',
#      'nis_beneficiario': 20905092141,
#      'cpf_beneficiario': '***.428.124-**',
#      'nome_beneficiario': 'ROBECIANO JOSE DA SILVA',
#      'nis_responsavel': 16385312985,
#      'cpf_responsavel': '***.680.164-**',
#      'nome_responsavel': 'CRISTIANE MARIA PEREIRA CORREIA',
#      'enquadramento': 'BOLSA FAMILIA',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '600,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'IpfOhXUB0pJdUuAdVmBG',
#     '_score': 1.0,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'PE',
#      'codigo_municipio_ibge': 2611903.0,
#      'nome_municipio': 'RIO FORMOSO',
#      'nis_beneficiario': 20905077673,
#      'cpf_beneficiario': '***.142.844-**',
#      'nome_beneficiario': 'ROBERIANA MARIA DA SILVA',
#      'nis_responsavel': 20905077673,
#      'cpf_responsavel': '***.142.844-**',
#      'nome_responsavel': 'ROBERIANA MARIA DA SILVA',
#      'enquadramento': 'BOLSA FAMILIA',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '1200,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'I5fOhXUB0pJdUuAdVmBG',
#     '_score': 1.0,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'PE',
#      'codigo_municipio_ibge': 2611903.0,
#      'nome_municipio': 'RIO FORMOSO',
#      'nis_beneficiario': 16548226799,
#      'cpf_beneficiario': '***.983.314-**',
#      'nome_beneficiario': 'ROBERICA ALVES DA SILVA',
#      'nis_responsavel': 16548226799,
#      'cpf_responsavel': '***.983.314-**',
#      'nome_responsavel': 'ROBERICA ALVES DA SILVA',
#      'enquadramento': 'BOLSA FAMILIA',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '1200,00'}}]}}

# %% [markdown]
# ### Por padrão do elasticsearch, as consultas comuns só retornam 10 documentos. Para aumentar o total de registros, é utilizado o parâmetro <i> size <i/>

# %%
body = {
  "query": {
    "match_all": {}
  },
  "size": "20"
}

# %%
result = es_client.search(index=index, body=body)

print("Total de registros ", len(result["hits"]["hits"]))
result
# Out:
# Total de registros  20
# {'took': 4,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'gte'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'GpfOhXUB0pJdUuAdVmBG',
#     '_score': 1.0,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'PE',
#      'codigo_municipio_ibge': 2611903.0,
#      'nome_municipio': 'RIO FORMOSO',
#      'nis_beneficiario': 0,
#      'cpf_beneficiario': '***.500.374-**',
#      'nome_beneficiario': 'RIVALDO SANTOS TIBURCIO',
#      'nis_responsavel': -2,
#      'cpf_responsavel': None,
#      'nome_responsavel': 'Não se aplica',
#      'enquadramento': 'EXTRA CADUN',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '600,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'G5fOhXUB0pJdUuAdVmBG',
#     '_score': 1.0,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'PE',
#      'codigo_municipio_ibge': 2611903.0,
#      'nome_municipio': 'RIO FORMOSO',
#      'nis_beneficiario': 0,
#      'cpf_beneficiario': '***.025.374-**',
#      'nome_beneficiario': 'RIVANILDA BATISTA DE OLIVEIRA',
#      'nis_responsavel': -2,
#      'cpf_responsavel': None,
#      'nome_responsavel': 'Não se aplica',
#      'enquadramento': 'EXTRA CADUN',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '1200,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'HJfOhXUB0pJdUuAdVmBG',
#     '_score': 1.0,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'PE',
#      'codigo_municipio_ibge': 2611903.0,
#      'nome_municipio': 'RIO FORMOSO',
#      'nis_beneficiario': 0,
#      'cpf_beneficiario': '***.245.724-**',
#      'nome_beneficiario': 'RIVANILDO SEBASTIAO DA SILVA',
#      'nis_responsavel': -2,
#      'cpf_responsavel': None,
#      'nome_responsavel': 'Não se aplica',
#      'enquadramento': 'EXTRA CADUN',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '600,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'HZfOhXUB0pJdUuAdVmBG',
#     '_score': 1.0,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'PE',
#      'codigo_municipio_ibge': 2611903.0,
#      'nome_municipio': 'RIO FORMOSO',
#      'nis_beneficiario': 16579842491,
#      'cpf_beneficiario': '***.510.494-**',
#      'nome_beneficiario': 'RIZOMAR MARIA DA SILVA',
#      'nis_responsavel': 16579842491,
#      'cpf_responsavel': '***.510.494-**',
#      'nome_responsavel': 'RIZOMAR MARIA DA SILVA',
#      'enquadramento': 'BOLSA FAMILIA',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '1200,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'HpfOhXUB0pJdUuAdVmBG',
#     '_score': 1.0,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'PE',
#      'codigo_municipio_ibge': 2611903.0,
#      'nome_municipio': 'RIO FORMOSO',
#      'nis_beneficiario': 16573547773,
#      'cpf_beneficiario': '***.808.374-**',
#      'nome_beneficiario': 'RIZONETE MARIA DO CARMO',
#      'nis_responsavel': -2,
#      'cpf_responsavel': None,
#      'nome_responsavel': 'Não se aplica',
#      'enquadramento': 'CADUN NAO BOLSA',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '600,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'H5fOhXUB0pJdUuAdVmBG',
#     '_score': 1.0,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'PE',
#      'codigo_municipio_ibge': 2611903.0,
#      'nome_municipio': 'RIO FORMOSO',
#      'nis_beneficiario': 16699033418,
#      'cpf_beneficiario': '***.765.614-**',
#      'nome_beneficiario': 'RIZONILDO FERREIRA DOS SANTOS',
#      'nis_responsavel': -2,
#      'cpf_responsavel': None,
#      'nome_responsavel': 'Não se aplica',
#      'enquadramento': 'CADUN NAO BOLSA',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '600,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'IJfOhXUB0pJdUuAdVmBG',
#     '_score': 1.0,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'PE',
#      'codigo_municipio_ibge': 2611903.0,
#      'nome_municipio': 'RIO FORMOSO',
#      'nis_beneficiario': 0,
#      'cpf_beneficiario': '***.812.844-**',
#      'nome_beneficiario': 'ROANNA ROCELI NASCIMENTO SANTOS',
#      'nis_responsavel': -2,
#      'cpf_responsavel': None,
#      'nome_responsavel': 'Não se aplica',
#      'enquadramento': 'EXTRA CADUN',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '600,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'IZfOhXUB0pJdUuAdVmBG',
#     '_score': 1.0,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'PE',
#      'codigo_municipio_ibge': 2611903.0,
#      'nome_municipio': 'RIO FORMOSO',
#      'nis_beneficiario': 20905092141,
#      'cpf_beneficiario': '***.428.124-**',
#      'nome_beneficiario': 'ROBECIANO JOSE DA SILVA',
#      'nis_responsavel': 16385312985,
#      'cpf_responsavel': '***.680.164-**',
#      'nome_responsavel': 'CRISTIANE MARIA PEREIRA CORREIA',
#      'enquadramento': 'BOLSA FAMILIA',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '600,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'IpfOhXUB0pJdUuAdVmBG',
#     '_score': 1.0,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'PE',
#      'codigo_municipio_ibge': 2611903.0,
#      'nome_municipio': 'RIO FORMOSO',
#      'nis_beneficiario': 20905077673,
#      'cpf_beneficiario': '***.142.844-**',
#      'nome_beneficiario': 'ROBERIANA MARIA DA SILVA',
#      'nis_responsavel': 20905077673,
#      'cpf_responsavel': '***.142.844-**',
#      'nome_responsavel': 'ROBERIANA MARIA DA SILVA',
#      'enquadramento': 'BOLSA FAMILIA',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '1200,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'I5fOhXUB0pJdUuAdVmBG',
#     '_score': 1.0,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'PE',
#      'codigo_municipio_ibge': 2611903.0,
#      'nome_municipio': 'RIO FORMOSO',
#      'nis_beneficiario': 16548226799,
#      'cpf_beneficiario': '***.983.314-**',
#      'nome_beneficiario': 'ROBERICA ALVES DA SILVA',
#      'nis_responsavel': 16548226799,
#      'cpf_responsavel': '***.983.314-**',
#      'nome_responsavel': 'ROBERICA ALVES DA SILVA',
#      'enquadramento': 'BOLSA FAMILIA',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '1200,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'JJfOhXUB0pJdUuAdVmBG',
#     '_score': 1.0,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'PE',
#      'codigo_municipio_ibge': 2611903.0,
#      'nome_municipio': 'RIO FORMOSO',
#      'nis_beneficiario': 16674168875,
#      'cpf_beneficiario': '***.934.154-**',
#      'nome_beneficiario': 'ROBERICA DA SILVA CARVALHO',
#      'nis_responsavel': 16674168875,
#      'cpf_responsavel': '***.934.154-**',
#      'nome_responsavel': 'ROBERICA DA SILVA CARVALHO',
#      'enquadramento': 'BOLSA FAMILIA',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '600,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'JZfOhXUB0pJdUuAdVmBG',
#     '_score': 1.0,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'PE',
#      'codigo_municipio_ibge': 2611903.0,
#      'nome_municipio': 'RIO FORMOSO',
#      'nis_beneficiario': 16561061943,
#      'cpf_beneficiario': '***.398.594-**',
#      'nome_beneficiario': 'ROBERICA MARIA DOS SANTOS',
#      'nis_responsavel': 16561061943,
#      'cpf_responsavel': '***.398.594-**',
#      'nome_responsavel': 'ROBERICA MARIA DOS SANTOS',
#      'enquadramento': 'BOLSA FAMILIA',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '1200,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'JpfOhXUB0pJdUuAdVmBG',
#     '_score': 1.0,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'PE',
#      'codigo_municipio_ibge': 2611903.0,
#      'nome_municipio': 'RIO FORMOSO',
#      'nis_beneficiario': 16561062222,
#      'cpf_beneficiario': '***.236.654-**',
#      'nome_beneficiario': 'ROBERLAN JOSE DOS SANTOS',
#      'nis_responsavel': 16385578985,
#      'cpf_responsavel': '***.120.824-**',
#      'nome_responsavel': 'MARIA JOSE DOS SANTOS',
#      'enquadramento': 'BOLSA FAMILIA',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '600,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'J5fOhXUB0pJdUuAdVmBG',
#     '_score': 1.0,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'PE',
#      'codigo_municipio_ibge': 2611903.0,
#      'nome_municipio': 'RIO FORMOSO',
#      'nis_beneficiario': 0,
#      'cpf_beneficiario': '***.331.434-**',
#      'nome_beneficiario': 'ROBERLANDIO ELIAS DO NASCIMENTO',
#      'nis_responsavel': -2,
#      'cpf_responsavel': None,
#      'nome_responsavel': 'Não se aplica',
#      'enquadramento': 'EXTRA CADUN',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '600,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'KJfOhXUB0pJdUuAdVmBG',
#     '_score': 1.0,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'PE',
#      'codigo_municipio_ibge': 2611903.0,
#      'nome_municipio': 'RIO FORMOSO',
#      'nis_beneficiario': 16576714573,
#      'cpf_beneficiario': '***.751.464-**',
#      'nome_beneficiario': 'ROBERLANIA MARIA SANTOS NASCIMENTO',
#      'nis_responsavel': 16576714573,
#      'cpf_responsavel': '***.751.464-**',
#      'nome_responsavel': 'ROBERLANIA MARIA SANTOS NASCIMENTO',
#      'enquadramento': 'BOLSA FAMILIA',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '1200,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'KZfOhXUB0pJdUuAdVmBG',
#     '_score': 1.0,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'PE',
#      'codigo_municipio_ibge': 2611903.0,
#      'nome_municipio': 'RIO FORMOSO',
#      'nis_beneficiario': 16695854026,
#      'cpf_beneficiario': '***.488.044-**',
#      'nome_beneficiario': 'ROBERT DA SILVA',
#      'nis_responsavel': -2,
#      'cpf_responsavel': None,
#      'nome_responsavel': 'Não se aplica',
#      'enquadramento': 'CADUN NAO BOLSA',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '600,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'KpfOhXUB0pJdUuAdVmBG',
#     '_score': 1.0,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'PE',
#      'codigo_municipio_ibge': 2611903.0,
#      'nome_municipio': 'RIO FORMOSO',
#      'nis_beneficiario': 16548227167,
#      'cpf_beneficiario': '***.858.854-**',
#      'nome_beneficiario': 'ROBERTA ALVES DA SILVA',
#      'nis_responsavel': 16548227167,
#      'cpf_responsavel': '***.858.854-**',
#      'nome_responsavel': 'ROBERTA ALVES DA SILVA',
#      'enquadramento': 'BOLSA FAMILIA',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '600,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'K5fOhXUB0pJdUuAdVmBG',
#     '_score': 1.0,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'PE',
#      'codigo_municipio_ibge': 2611903.0,
#      'nome_municipio': 'RIO FORMOSO',
#      'nis_beneficiario': 16679697515,
#      'cpf_beneficiario': '***.536.604-**',
#      'nome_beneficiario': 'ROBERTA AUGUSTA SANTOS SILVA',
#      'nis_responsavel': 16679697515,
#      'cpf_responsavel': '***.536.604-**',
#      'nome_responsavel': 'ROBERTA AUGUSTA SANTOS SILVA',
#      'enquadramento': 'BOLSA FAMILIA',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '1200,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'LJfOhXUB0pJdUuAdVmBG',
#     '_score': 1.0,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'PE',
#      'codigo_municipio_ibge': 2611903.0,
#      'nome_municipio': 'RIO FORMOSO',
#      'nis_beneficiario': 13977998454,
#      'cpf_beneficiario': '***.283.544-**',
#      'nome_beneficiario': 'ROBERTA CASSIA DE OLIVEIRA',
#      'nis_responsavel': 13977998454,
#      'cpf_responsavel': '***.283.544-**',
#      'nome_responsavel': 'ROBERTA CASSIA DE OLIVEIRA',
#      'enquadramento': 'BOLSA FAMILIA',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '1200,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'LZfOhXUB0pJdUuAdVmBG',
#     '_score': 1.0,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'PE',
#      'codigo_municipio_ibge': 2611903.0,
#      'nome_municipio': 'RIO FORMOSO',
#      'nis_beneficiario': 13897745649,
#      'cpf_beneficiario': '***.029.394-**',
#      'nome_beneficiario': 'ROBERTA CRISTINA DOS SANTOS',
#      'nis_responsavel': 13897745649,
#      'cpf_responsavel': '***.029.394-**',
#      'nome_responsavel': 'ROBERTA CRISTINA DOS SANTOS',
#      'enquadramento': 'BOLSA FAMILIA',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '600,00'}}]}}

# %%
body = {
  "query": {
    "match": {
      "nome_municipio": "MANAUS"
    }
  }
}

# %%
result = es_client.search(index=index, body=body)

print("Total de registros ", len(result["hits"]["hits"]))
result
# Out:
# Total de registros  10
# {'took': 4,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'gte'},
#   'max_score': 2.5222366e-06,
#   'hits': [{'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'NRxuhnUB0pJdUuAdK-x-',
#     '_score': 2.5222366e-06,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'AM',
#      'codigo_municipio_ibge': 1302603.0,
#      'nome_municipio': 'MANAUS',
#      'nis_beneficiario': 0,
#      'cpf_beneficiario': '***.221.122-**',
#      'nome_beneficiario': 'IRLIS DE SOUZA SAMPAIO',
#      'nis_responsavel': -2,
#      'cpf_responsavel': None,
#      'nome_responsavel': 'Não se aplica',
#      'enquadramento': 'EXTRA CADUN',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '600,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'NhxuhnUB0pJdUuAdK-x-',
#     '_score': 2.5222366e-06,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'AM',
#      'codigo_municipio_ibge': 1302603.0,
#      'nome_municipio': 'MANAUS',
#      'nis_beneficiario': 0,
#      'cpf_beneficiario': '***.592.442-**',
#      'nome_beneficiario': 'IRLIS LEI DE JESUS BAIA',
#      'nis_responsavel': -2,
#      'cpf_responsavel': None,
#      'nome_responsavel': 'Não se aplica',
#      'enquadramento': 'EXTRA CADUN',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '600,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'NxxuhnUB0pJdUuAdK-x-',
#     '_score': 2.5222366e-06,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'AM',
#      'codigo_municipio_ibge': 1302603.0,
#      'nome_municipio': 'MANAUS',
#      'nis_beneficiario': 16278561957,
#      'cpf_beneficiario': '***.883.062-**',
#      'nome_beneficiario': 'IRLIS SANTOS RIBEIRO',
#      'nis_responsavel': 16278561957,
#      'cpf_responsavel': '***.883.062-**',
#      'nome_responsavel': 'IRLIS SANTOS RIBEIRO',
#      'enquadramento': 'BOLSA FAMILIA',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '1200,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'OBxuhnUB0pJdUuAdK-x-',
#     '_score': 2.5222366e-06,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'AM',
#      'codigo_municipio_ibge': 1302603.0,
#      'nome_municipio': 'MANAUS',
#      'nis_beneficiario': 0,
#      'cpf_beneficiario': '***.492.162-**',
#      'nome_beneficiario': 'IRLON JORDAO DE OLIVEIRA',
#      'nis_responsavel': -2,
#      'cpf_responsavel': None,
#      'nome_responsavel': 'Não se aplica',
#      'enquadramento': 'EXTRA CADUN',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '600,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'ORxuhnUB0pJdUuAdK-x-',
#     '_score': 2.5222366e-06,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'AM',
#      'codigo_municipio_ibge': 1302603.0,
#      'nome_municipio': 'MANAUS',
#      'nis_beneficiario': 0,
#      'cpf_beneficiario': '***.365.952-**',
#      'nome_beneficiario': 'IRLONEI CARDOSO ALVES',
#      'nis_responsavel': -2,
#      'cpf_responsavel': None,
#      'nome_responsavel': 'Não se aplica',
#      'enquadramento': 'EXTRA CADUN',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '600,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'OhxuhnUB0pJdUuAdK-x-',
#     '_score': 2.5222366e-06,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'AM',
#      'codigo_municipio_ibge': 1302603.0,
#      'nome_municipio': 'MANAUS',
#      'nis_beneficiario': 0,
#      'cpf_beneficiario': '***.190.912-**',
#      'nome_beneficiario': 'IRLUBIA XAVIER DINIZ',
#      'nis_responsavel': -2,
#      'cpf_responsavel': None,
#      'nome_responsavel': 'Não se aplica',
#      'enquadramento': 'EXTRA CADUN',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '1200,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'OxxuhnUB0pJdUuAdK-x-',
#     '_score': 2.5222366e-06,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'AM',
#      'codigo_municipio_ibge': 1302603.0,
#      'nome_municipio': 'MANAUS',
#      'nis_beneficiario': 0,
#      'cpf_beneficiario': '***.393.942-**',
#      'nome_beneficiario': 'IRMA BEATRIZ BARROS DE ARAUJO',
#      'nis_responsavel': -2,
#      'cpf_responsavel': None,
#      'nome_responsavel': 'Não se aplica',
#      'enquadramento': 'EXTRA CADUN',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '1200,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'PBxuhnUB0pJdUuAdK-x-',
#     '_score': 2.5222366e-06,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'AM',
#      'codigo_municipio_ibge': 1302603.0,
#      'nome_municipio': 'MANAUS',
#      'nis_beneficiario': 0,
#      'cpf_beneficiario': '***.099.272-**',
#      'nome_beneficiario': 'IRMA CHRISTINA RIBEIRO',
#      'nis_responsavel': -2,
#      'cpf_responsavel': None,
#      'nome_responsavel': 'Não se aplica',
#      'enquadramento': 'EXTRA CADUN',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '1200,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'PRxuhnUB0pJdUuAdK-x-',
#     '_score': 2.5222366e-06,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'AM',
#      'codigo_municipio_ibge': 1302603.0,
#      'nome_municipio': 'MANAUS',
#      'nis_beneficiario': 0,
#      'cpf_beneficiario': '***.874.322-**',
#      'nome_beneficiario': 'IRMA FERRAZ DA SILVA',
#      'nis_responsavel': -2,
#      'cpf_responsavel': None,
#      'nome_responsavel': 'Não se aplica',
#      'enquadramento': 'EXTRA CADUN',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '600,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'PhxuhnUB0pJdUuAdK-x-',
#     '_score': 2.5222366e-06,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'AM',
#      'codigo_municipio_ibge': 1302603.0,
#      'nome_municipio': 'MANAUS',
#      'nis_beneficiario': 0,
#      'cpf_beneficiario': '***.104.492-**',
#      'nome_beneficiario': 'IRMA GENESTE',
#      'nis_responsavel': -2,
#      'cpf_responsavel': None,
#      'nome_responsavel': 'Não se aplica',
#      'enquadramento': 'EXTRA CADUN',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '1200,00'}}]}}

# %% [markdown]
# ### Consultas com valores combinados

# %%
body = {
  "query": {
    "bool": {
        "must": [
            {"match": {"nome_municipio": "MANAUS"}},
            {"match": {"nome_beneficiario": "Maria"}}
        ]
    }
  }
}

# %%
result = es_client.search(index=index, body=body)

print("Total de registros ", len(result["hits"]["hits"]))
result
# Out:
# Total de registros  10
# {'took': 25,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'gte'},
#   'max_score': 2.3627918,
#   'hits': [{'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'vh1uhnUB0pJdUuAdUqio',
#     '_score': 2.3627918,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'AM',
#      'codigo_municipio_ibge': 1302603.0,
#      'nome_municipio': 'MANAUS',
#      'nis_beneficiario': 0,
#      'cpf_beneficiario': '***.833.562-**',
#      'nome_beneficiario': 'JOSE MARIA',
#      'nis_responsavel': -2,
#      'cpf_responsavel': None,
#      'nome_responsavel': 'Não se aplica',
#      'enquadramento': 'EXTRA CADUN',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '600,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'yB5uhnUB0pJdUuAdn-0V',
#     '_score': 2.3627918,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'AM',
#      'codigo_municipio_ibge': 1302603.0,
#      'nome_municipio': 'MANAUS',
#      'nis_beneficiario': 16460557536,
#      'cpf_beneficiario': '***.380.112-**',
#      'nome_beneficiario': 'MARIA ANDRADE',
#      'nis_responsavel': 16460557536,
#      'cpf_responsavel': '***.380.112-**',
#      'nome_responsavel': 'MARIA ANDRADE',
#      'enquadramento': 'BOLSA FAMILIA',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '600,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'xx5uhnUB0pJdUuAdofX_',
#     '_score': 2.3627918,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'AM',
#      'codigo_municipio_ibge': 1302603.0,
#      'nome_municipio': 'MANAUS',
#      'nis_beneficiario': 23773000428,
#      'cpf_beneficiario': '***.822.072-**',
#      'nome_beneficiario': 'MARIA BALTAZAR',
#      'nis_responsavel': -2,
#      'cpf_responsavel': None,
#      'nome_responsavel': 'Não se aplica',
#      'enquadramento': 'CADUN NAO BOLSA',
#      'parcela': '1ª',
#      'observacao': 'Retido: Avaliação por divergências cadastrais',
#      'valor_beneficio': '600,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'yB5uhnUB0pJdUuAdofX_',
#     '_score': 2.3627918,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'AM',
#      'codigo_municipio_ibge': 1302603.0,
#      'nome_municipio': 'MANAUS',
#      'nis_beneficiario': 0,
#      'cpf_beneficiario': '***.753.002-**',
#      'nome_beneficiario': 'MARIA BANDEIRA',
#      'nis_responsavel': -2,
#      'cpf_responsavel': None,
#      'nome_responsavel': 'Não se aplica',
#      'enquadramento': 'EXTRA CADUN',
#      'parcela': '1ª',
#      'observacao': 'Retido: Avaliação por divergências cadastrais',
#      'valor_beneficio': '600,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'eh5uhnUB0pJdUuAdofb_',
#     '_score': 2.3627918,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'AM',
#      'codigo_municipio_ibge': 1302603.0,
#      'nome_municipio': 'MANAUS',
#      'nis_beneficiario': 0,
#      'cpf_beneficiario': '***.912.262-**',
#      'nome_beneficiario': 'MARIA BERMUDEZ',
#      'nis_responsavel': -2,
#      'cpf_responsavel': None,
#      'nome_responsavel': 'Não se aplica',
#      'enquadramento': 'EXTRA CADUN',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '1200,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'hR5uhnUB0pJdUuAdoff_',
#     '_score': 2.3627918,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'AM',
#      'codigo_municipio_ibge': 1302603.0,
#      'nome_municipio': 'MANAUS',
#      'nis_beneficiario': 16493995583,
#      'cpf_beneficiario': '***.383.902-**',
#      'nome_beneficiario': 'MARIA CASTRO',
#      'nis_responsavel': -2,
#      'cpf_responsavel': None,
#      'nome_responsavel': 'Não se aplica',
#      'enquadramento': 'CADUN NAO BOLSA',
#      'parcela': '1ª',
#      'observacao': 'Retido: Avaliação por divergências cadastrais',
#      'valor_beneficio': '600,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'Hh5uhnUB0pJdUuAdovv6',
#     '_score': 2.3627918,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'AM',
#      'codigo_municipio_ibge': 1302603.0,
#      'nome_municipio': 'MANAUS',
#      'nis_beneficiario': 17013640113,
#      'cpf_beneficiario': '***.060.082-**',
#      'nome_beneficiario': 'MARIA COSMA',
#      'nis_responsavel': -2,
#      'cpf_responsavel': None,
#      'nome_responsavel': 'Não se aplica',
#      'enquadramento': 'CADUN NAO BOLSA',
#      'parcela': '1ª',
#      'observacao': 'Retido: Avaliação por divergências cadastrais',
#      'valor_beneficio': '600,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'Ix5uhnUB0pJdUuAdovv6',
#     '_score': 2.3627918,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'AM',
#      'codigo_municipio_ibge': 1302603.0,
#      'nome_municipio': 'MANAUS',
#      'nis_beneficiario': 0,
#      'cpf_beneficiario': '***.161.892-**',
#      'nome_beneficiario': 'MARIA COSTA',
#      'nis_responsavel': -2,
#      'cpf_responsavel': None,
#      'nome_responsavel': 'Não se aplica',
#      'enquadramento': 'EXTRA CADUN',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '600,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'UB5uhnUB0pJdUuAdo_xk',
#     '_score': 2.3627918,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'AM',
#      'codigo_municipio_ibge': 1302603.0,
#      'nome_municipio': 'MANAUS',
#      'nis_beneficiario': 16363793719,
#      'cpf_beneficiario': '***.661.392-**',
#      'nome_beneficiario': 'MARIA CRUZ',
#      'nis_responsavel': 16363793719,
#      'cpf_responsavel': '***.661.392-**',
#      'nome_responsavel': 'MARIA CRUZ',
#      'enquadramento': 'BOLSA FAMILIA',
#      'parcela': '1ª',
#      'observacao': 'Não há',
#      'valor_beneficio': '1200,00'}},
#    {'_index': 'auxilio-emergencial',
#     '_type': '_doc',
#     '_id': 'nR9uhnUB0pJdUuAdrSjk',
#     '_score': 2.3627918,
#     '_source': {'mes_disponibilizacao': 202004,
#      'uf': 'AM',
#      'codigo_municipio_ibge': 1302603.0,
#      'nome_municipio': 'MANAUS',
#      'nis_beneficiario': 23888059182,
#      'cpf_beneficiario': '***.691.262-**',
#      'nome_beneficiario': 'MARIA FIGUEIREDO',
#      'nis_responsavel': -2,
#      'cpf_responsavel': None,
#      'nome_responsavel': 'Não se aplica',
#      'enquadramento': 'CADUN NAO BOLSA',
#      'parcela': '1ª',
#      'observacao': 'Retido: Avaliação por divergências cadastrais',
#      'valor_beneficio': '600,00'}}]}}
